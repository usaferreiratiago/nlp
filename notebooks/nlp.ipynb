# %%
person = "Jose"

# %%
print ("my name is {}".format(person))
# Out:
# my name is Jose

# %%
print(f"my name is {person}")
# Out:
# my name is Jose

# %%
d = {'a':123, 'b':456 }

# %%
print(f"my number is {d['a']}")
# Out:
# my number is 123

# %%
mylist = [0,1,2]

# %%
print(f"my number is {mylist[0]}")
# Out:
# my number is 0

# %%
library = [('Author', 'Topic', 'Pages'), ('Twain', 'Rafting', 601), ('Feynman', 'Physics', 95), ('Hamilton', 'Mythology', 144)]

# %%
library
# Out:
# [('Author', 'Topic', 'Pages'),
#  ('Twain', 'Rafting', 601),
#  ('Feynman', 'Physics', 95),
#  ('Hamilton', 'Mythology', 144)]

# %%
for book in library:
    print(book)
# Out:
# ('Author', 'Topic', 'Pages')
# ('Twain', 'Rafting', 601)
# ('Feynman', 'Physics', 95)
# ('Hamilton', 'Mythology', 144)

# %%
for book in library:
    print(f"Author is {book[0]}")
# Out:
# Author is Author
# Author is Twain
# Author is Feynman
# Author is Hamilton

# %%
for author,topic,pages in library:
    print(f"Author is {author}")
# Out:
# Author is Author
# Author is Twain
# Author is Feynman
# Author is Hamilton

# %%
for author,topic,pages in library:
    print(f"{author} {topic} {pages}")
# Out:
# Author Topic Pages
# Twain Rafting 601
# Feynman Physics 95
# Hamilton Mythology 144

# %%
for author,topic,pages in library:
    print(f"{author:{10}} {topic:{30}} {pages:.>{10}}")
# Out:
# Author     Topic                          .....Pages
# Twain      Rafting                        .......601
# Feynman    Physics                        ........95
# Hamilton   Mythology                      .......144

# %%
from datetime import datetime

# %%
today = datetime(year=2019,month=2,day=28)

# %%
print(f"{today}")
# Out:
# 2019-02-28 00:00:00

# %%
today
# Out:
# datetime.datetime(2019, 2, 28, 0, 0)

# %%
# %%writefile test.txt
# Hello, this is a quick test file.
# This is the second line of the file.
# Out:
# Writing test.txt

# %%
myfile = open('whoops.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 myfile = open('whoops.txt')
#
# File ~/Documents/nlp/.venv/lib/python3.14/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'whoops.txt'

# %%
pwd # type: ignore
# Out:
# '/home/vboxuser/Documents/nlp/notebooks'

# %%
myfile = open('test.txt')

# %%
myfile
# Out:
# <_io.TextIOWrapper name='test.txt' mode='r' encoding='UTF-8'>

# %%
myfile = open('/home/vboxuser/Documents/nlp/notebooks/test.txt')

# %%
myfile.read()
# Out:
# 'Hello, this is a quick test file.\nThis is the second line of the file.\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello, this is a quick test file.\nThis is the second line of the file.\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
content = myfile.read()

# %%
print(content)
# Out:
# Hello, this is a quick test file.
# This is the second line of the file.

# %%
content
# Out:
# 'Hello, this is a quick test file.\nThis is the second line of the file.\n'

# %%
myfile.close()

# %%
myfile = open('test.txt')

# %%
myfile.readlines()
# Out:
# ['Hello, this is a quick test file.\n',
#  'This is the second line of the file.\n']

# %%
myfile.seek(0)
# Out:
# 0

# %%
mylines = myfile.readlines()

# %%
for line in mylines:
  print(line.split()[0])
# Out:
# Hello,
# This

# %%
myfile = open('test.txt','w+')

# %%
myfile.read()
# Out:
# ''

# %%
myfile.write('MY BRAND NEW TEXT')
# Out:
# 17

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'MY BRAND NEW TEXT'
