# %%
from PyPDF2 import  PdfReader

# %%
myfile = open('/home/vboxuser/Downloads/CNPJ.pdf', mode='rb')

# %%
pdf_reader = PyPDF2.PdfReader(myfile) # type: ignore

# %%
len(pdf_reader.pages)
# Out:
# 1

# %%
page_one = pdf_reader.pages[0]

# %%
print(page_one.extract_text())
# Out:
#  REPÚBLICA  FEDERA TIVA DO BRASIL   CADASTRO NACIONAL  DA PESSOA  JURÍDICA
#
# NÚMERO DE INSCRIÇÃO
# 17.437.384/0001-07
# MATRIZCOMPROVANTE DE INSCRIÇÃO E DE SITUAÇÃO
# CADASTRALDATA DE ABER TURA
# 19/01/2013
#
# NOME EMPRESARIAL
# TIAGO HENRIQUE RIBEIRO FERREIRA
#
# TÍTULO DO EST ABELECIMENT O (NOME DE F ANTASIA)
# REDSEG SOLUCOES EM REDES E SEGURANCA EM TIPOR TE
# ME
#
# CÓDIGO E DESCRIÇÃO DA  ATIVIDADE ECONÔMICA  PRINCIP AL
# 62.09-1-00 - Suporte técnico, manutenção e outros serviços em tecnologia da informação
#
# CÓDIGO E DESCRIÇÃO DAS ATIVIDADES ECONÔMICAS SECUNDÁRIAS
# 95.11-8-00 - Reparação e manutenção de computadores e de equipamentos periféricos
#
# CÓDIGO E DESCRIÇÃO DA  NATUREZA  JURÍDICA
# 213-5 - Empresário (Individual)
#
# LOGRADOURO
# R JOAQUIM MARTINS FERREIRANÚMERO
# 25COMPLEMENT O
# ********
#
# CEP
# 35.182-143BAIRRO/DISTRIT O
# NOSSA SENHORA DAS GRACASMUNICÍPIO
# TIMOTEOUF
# MG
#
# ENDEREÇO ELETRÔNICO
# CONTABILIDADEJML@GMAIL.COMTELEFONE
# (31) 3847-1020
#
# ...

# %%
mytext = page_one.extract_text()

# %%
myfile.close()

# %%
f = open('/home/vboxuser/Downloads/CNPJ.pdf', mode='rb')

# %%
pdf_reader = PyPDF2.PdfReader(f) # type: ignore

# %%
first_page = pdf_reader.pages[0]

# %%
pdf_writer = PyPDF2.PdfWriter() # type: ignore

# %%
pdf_writer.add_page(first_page)
# Out:
# {'/Type': '/Page',
#  '/Resources': {'/ProcSet': ['/PDF', '/Text', '/ImageB', '/ImageC', '/ImageI'],
#   '/ExtGState': {'/G3': {'/ca': 1, '/BM': '/Normal'},
#    '/G4': {'/CA': 1,
#     '/ca': 1,
#     '/LC': 0,
#     '/LJ': 0,
#     '/LW': 1,
#     '/ML': 4,
#     '/SA': True,
#     '/BM': '/Normal'}},
#   '/XObject': {'/X5': {'/Type': '/XObject',
#     '/Subtype': '/Image',
#     '/Width': 100,
#     '/Height': 104,
#     '/ColorSpace': ['/ICCBased', IndirectObject(8, 0, 137349340191056)],
#     '/SMask': {'/Type': '/XObject',
#      '/Subtype': '/Image',
#      '/Width': 100,
#      '/Height': 104,
#      '/ColorSpace': '/DeviceGray',
#      '/BitsPerComponent': 8,
#      '/Filter': '/FlateDecode'},
#     '/BitsPerComponent': 8,
#     '/Filter': '/FlateDecode'}},
#   '/Font': {'/F8': {'/Type': '/Font',
#     '/Subtype': '/Type0',
#     '/BaseFont': '/AAAAAA+LiberationSerif',
#     '/Encoding': '/Identity-H',
#     '/DescendantFonts': [IndirectObject(11, 0, 137349340191056)],
# ...

# %%
pdf_output = open ('/home/vboxuser/Downloads/MY_BRAND_NEW.pdf', 'wb')

# %%
pdf_writer.write(pdf_output)
# Out:
# (False, <_io.BufferedWriter name='/home/vboxuser/Downloads/MY_BRAND_NEW.pdf'>)

# %%
pdf_output.close()

# %%
f.close()

# %%
brand_new = open('/home/vboxuser/Downloads/MY_BRAND_NEW.pdf', 'rb')

pdf_reader = PdfReader(brand_new)

# %%
num_pages = len(reader.pages)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[315], line 1
# ----> 1 num_pages = len(reader.pages)
#
# NameError: name 'reader' is not defined
