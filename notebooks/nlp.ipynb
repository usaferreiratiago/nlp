# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(u'Tesla is look at buying U.S. startup for $6 million')

# %%
for token in doc:
  print(token.text)
# Out:
# Tesla
# is
# look
# at
# buying
# U.S.
# startup
# for
# $
# 6
# million
