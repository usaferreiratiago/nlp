# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')
# nlp = spacy.load('pt_core_news_sm')

# %%
doc = nlp(u'Tesla is look at buying U.S. startup for $6 million')

# %%
for token in doc:
  print(token.text)
# Out:
# Tesla
# is
# look
# at
# buying
# U.S.
# startup
# for
# $
# 6
# million

# %%
for token in doc:
  print(token.text,token.pos)
# Out:
# Tesla 96
# is 87
# look 100
# at 85
# buying 100
# U.S. 96
# startup 100
# for 85
# $ 99
# 6 93
# million 93

# %%
for token in doc:
  print(token.text,token.pos_)
# Out:
# Tesla PROPN
# is AUX
# look VERB
# at ADP
# buying VERB
# U.S. PROPN
# startup VERB
# for ADP
# $ SYM
# 6 NUM
# million NUM

# %%
for token in doc:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubjpass
# is AUX auxpass
# look VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.S. PROPN dobj
# startup VERB dobj
# for ADP prep
# $ SYM quantmod
# 6 NUM compound
# million NUM pobj

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x73e36d686c90>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x73e36d686150>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x73e36d641930>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x73e36d539890>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x73e36d440790>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x73e36d641bd0>)]

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc2 = nlp(u"Tesla isn't looking into startups anymore.")

# %%
for token in doc2:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc2 = nlp(u"Tesla isn't     looking into startups anymore.")

# %%
for token in doc2:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
#      SPACE dep
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc2[0]
# Out:
# Tesla

# %%
doc2[0].pos_
# Out:
# 'PROPN'

# %%
doc2[0].dep_
# Out:
# 'nsubj'

# %%
print(doc2[6].text)
# Out:
# startups

# %%
print(doc2[6].lemma_)
# Out:
# startup

# %%
print(doc2[6].is_alpha)
# Out:
# True

# %%
doc3 = nlp(u'Althoug commmoly attributed to John Lennon from his song "Beautiful Boy", \
           the phrase "Life is what happens to us while we are making other plans" was written by \
           cartoonist Allen Saunders and published in Reader\'s Digest in 1927, when Lennon was 17')

# %%
life_quote = doc3[16:30]

# %%
print(life_quote)
# Out:
# phrase "Life is what happens to us while we are making other plans

# %%
type(life_quote)
# Out:
# spacy.tokens.span.Span

# %%
type(doc3)
# Out:
# spacy.tokens.doc.Doc

# %%
doc4 = nlp(u"this is the first sentence. This is another sentence. This is the last sentence")

# %%
for sentence in doc4.sents:
  print(sentence)
# Out:
# this is the first sentence.
# This is another sentence.
# This is the last sentence

# %%
doc4[6]
# Out:
# This

# %%
doc4[6].is_sent_start
# Out:
# True

# %%
doc4[8].is_sent_start
# Out:
# False

# %%
mystring = '"We\'re moving to L.A.!"'

# %%
print(mystring)
# Out:
# "We're moving to L.A.!"

# %%
doc = nlp(mystring)

# %%
for token in doc:
  print(token.text)
# Out:
# "
# We
# 're
# moving
# to
# L.A.
# !
# "

# %%
doc2 = nlp(u"We're here to help! Send snail-mail, email support@oursite.com or visit us at http://www.oursite.com!")

# %%
for t in doc2:
  print(t)
# Out:
# We
# 're
# here
# to
# help
# !
# Send
# snail
# -
# mail
# ,
# email
# support@oursite.com
# or
# visit
# us
# at
# http://www.oursite.com
# !

# %%
doc3 = nlp(u"A 5km NYC cab ride costs $10.30")

# %%
for t in doc3:
  print(t)
# Out:
# A
# 5
# km
# NYC
# cab
# ride
# costs
# $
# 10.30

# %%
doc4 = nlp(u"Let's visit St. Louis in the U.S. next year.")

# %%
for t in doc4:
  print(t)
# Out:
# Let
# 's
# visit
# St.
# Louis
# in
# the
# U.S.
# next
# year
# .

# %%
len(doc4)
# Out:
# 11

# %%
doc4.vocab

# %%
len(doc4.vocab)
# Out:
# 837

# %%
doc5 = nlp(u"It is better to give than receive")

# %%
doc5[0]
# Out:
# It

# %%
doc5[2:5]
# Out:
# better to give
