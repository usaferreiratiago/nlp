# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')
# nlp = spacy.load('pt_core_news_sm')

# %%
doc = nlp(u'Tesla is look at buying U.S. startup for $6 million')

# %%
for token in doc:
  print(token.text)
# Out:
# Tesla
# is
# look
# at
# buying
# U.S.
# startup
# for
# $
# 6
# million

# %%
for token in doc:
  print(token.text,token.pos)
# Out:
# Tesla 96
# is 87
# look 100
# at 85
# buying 100
# U.S. 96
# startup 100
# for 85
# $ 99
# 6 93
# million 93

# %%
for token in doc:
  print(token.text,token.pos_)
# Out:
# Tesla PROPN
# is AUX
# look VERB
# at ADP
# buying VERB
# U.S. PROPN
# startup VERB
# for ADP
# $ SYM
# 6 NUM
# million NUM

# %%
for token in doc:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubjpass
# is AUX auxpass
# look VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.S. PROPN dobj
# startup VERB dobj
# for ADP prep
# $ SYM quantmod
# 6 NUM compound
# million NUM pobj

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x74072c9e3fb0>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x740731c81bb0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x74072ce55cb0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x74072de151d0>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x74072e57a410>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x74072ce55a80>)]

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc2 = nlp(u"Tesla isn't looking into startups anymore.")

# %%
for token in doc2:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc2 = nlp(u"Tesla isn't     looking into startups anymore.")

# %%
for token in doc2:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
#      SPACE dep
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct
