# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')
# nlp = spacy.load('pt_core_news_sm')

# %%
doc = nlp(u'Tesla is look at buying U.S. startup for $6 million')

# %%
for token in doc:
  print(token.text)
# Out:
# Tesla
# is
# look
# at
# buying
# U.S.
# startup
# for
# $
# 6
# million

# %%
for token in doc:
  print(token.text,token.pos)
# Out:
# Tesla 96
# is 87
# look 100
# at 85
# buying 100
# U.S. 96
# startup 100
# for 85
# $ 99
# 6 93
# million 93

# %%
for token in doc:
  print(token.text,token.pos_)
# Out:
# Tesla PROPN
# is AUX
# look VERB
# at ADP
# buying VERB
# U.S. PROPN
# startup VERB
# for ADP
# $ SYM
# 6 NUM
# million NUM

# %%
for token in doc:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubjpass
# is AUX auxpass
# look VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.S. PROPN dobj
# startup VERB dobj
# for ADP prep
# $ SYM quantmod
# 6 NUM compound
# million NUM pobj

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7a78793c5310>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7a78793c5730>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7a7879399bd0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7a7879736cd0>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7a7879348d90>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7a7879399d20>)]

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc2 = nlp(u"Tesla isn't looking into startups anymore.")

# %%
for token in doc2:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc2 = nlp(u"Tesla isn't     looking into startups anymore.")

# %%
for token in doc2:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
#      SPACE dep
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc2[0]
# Out:
# Tesla

# %%
doc2[0].pos_
# Out:
# 'PROPN'

# %%
doc2[0].dep_
# Out:
# 'nsubj'

# %%
print(doc2[6].text)
# Out:
# startups

# %%
print(doc2[6].lemma_)
# Out:
# startup

# %%
print(doc2[6].is_alpha)
# Out:
# True

# %%
doc3 = nlp(u'Althoug commmoly attributed to John Lennon from his song "Beautiful Boy", \
           the phrase "Life is what happens to us while we are making other plans" was written by \
           cartoonist Allen Saunders and published in Reader\'s Digest in 1927, when Lennon was 17')

# %%
life_quote = doc3[16:30]

# %%
print(life_quote)
# Out:
# phrase "Life is what happens to us while we are making other plans

# %%
type(life_quote)
# Out:
# spacy.tokens.span.Span

# %%
type(doc3)
# Out:
# spacy.tokens.doc.Doc

# %%
doc4 = nlp(u"this is the first sentence. This is another sentence. This is the last sentence")

# %%
for sentence in doc4.sents:
  print(sentence)
# Out:
# this is the first sentence.
# This is another sentence.
# This is the last sentence

# %%
doc4[6]
# Out:
# This

# %%
doc4[6].is_sent_start
# Out:
# True

# %%
doc4[8].is_sent_start
# Out:
# False

# %%
mystring = '"We\'re moving to L.A.!"'

# %%
print(mystring)
# Out:
# "We're moving to L.A.!"

# %%
doc = nlp(mystring)

# %%
for token in doc:
  print(token.text)
# Out:
# "
# We
# 're
# moving
# to
# L.A.
# !
# "

# %%
doc2 = nlp(u"We're here to help! Send snail-mail, email support@oursite.com or visit us at http://www.oursite.com!")

# %%
for t in doc2:
  print(t)
# Out:
# We
# 're
# here
# to
# help
# !
# Send
# snail
# -
# mail
# ,
# email
# support@oursite.com
# or
# visit
# us
# at
# http://www.oursite.com
# !

# %%
doc3 = nlp(u"A 5km NYC cab ride costs $10.30")

# %%
for t in doc3:
  print(t)
# Out:
# A
# 5
# km
# NYC
# cab
# ride
# costs
# $
# 10.30

# %%
doc4 = nlp(u"Let's visit St. Louis in the U.S. next year.")

# %%
for t in doc4:
  print(t)
# Out:
# Let
# 's
# visit
# St.
# Louis
# in
# the
# U.S.
# next
# year
# .

# %%
len(doc4)
# Out:
# 11

# %%
doc4.vocab

# %%
len(doc4.vocab)
# Out:
# 837

# %%
doc5 = nlp(u"It is better to give than receive")

# %%
doc5[0]
# Out:
# It

# %%
doc5[2:5]
# Out:
# better to give

# %%
doc5[0] = 'test'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 doc5[0] = 'test'
#
# TypeError: 'spacy.tokens.doc.Doc' object does not support item assignment

# %%
doc8 = nlp(u"Apple to build a Hong Kong factroy for $6 million")

# %%
for token in doc8:
  print(token.text, end=' | ')
# Out:
# Apple | to | build | a | Hong | Kong | factroy | for | $ | 6 | million |

# %%
for entity in doc8.ents:
  print(entity)
# Out:
# Apple
# Hong Kong
# $6 million

# %%
for entity in doc8.ents:
  print(entity)
  print(entity.label_)
  print(str(spacy.explain(entity.label_)))
  print('\n')
# Out:
# Apple
# ORG
# Companies, agencies, institutions, etc.
#
#
# Hong Kong
# GPE
# Countries, cities, states
#
#
# $6 million
# MONEY
# Monetary values, including unit

# %%
doc9 = nlp(u"Autonomous cars shift insurance liability toward manufacturers.")

# %%
for chunck in doc9.noun_chunks:
  print(chunck)
# Out:
# Autonomous cars
# insurance liability
# manufacturers

# %%
from spacy import displacy

# %%
doc = nlp(u"Apple is going to build a U.K. factory for $6 million.")

# %%
displacy.render(doc,style='dep', jupyter='True',options={'distance':110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7a5f82ed621842e594a305748cc8b30a-0" class="displacy" width="1370" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
# ...

# %%
doc = nlp(u"Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million.")

# %%
displacy.render(doc,style='ent', jupyter='True')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
# ...

# %%
doc = nlp(u"This is a sentence.")
displacy.serve(doc,style='dep')
# Out:
# /home/vboxuser/Documents/nlp/.venv/lib/python3.11/site-packages/spacy/displacy/__init__.py:108: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# ...

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer

# %%
p_stemmer = PorterStemmer()

# %%
words = ['run','runner','ran','runs','easily','fairly','fairness']

# %%
for word in words:
  print(word + '----->' +p_stemmer.stem(word))
# Out:
# run----->run
# runner----->runner
# ran----->ran
# runs----->run
# easily----->easili
# fairly----->fairli
# fairness----->fair

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
s_stemmer = SnowballStemmer(language='english')

# %%
for word in words:
  print(word + '  ----->' +s_stemmer.stem(word))
# Out:
# run  ----->run
# runner  ----->runner
# ran  ----->ran
# runs  ----->run
# easily  ----->easili
# fairly  ----->fair
# fairness  ----->fair

# %%
words = ['generous','generation','generously','generate']

# %%
for word in words:
  print(word + '  ----->' +s_stemmer.stem(word))
# Out:
# generous  ----->generous
# generation  ----->generat
# generously  ----->generous
# generate  ----->generat

# %%
doc1 = nlp(u"I am a runner running in a race because I love to run since I ran today")

# %%
for token in doc1:
  print(token.text,'\t',token.pos_,'\t',token.lemma,'\t',token.lemma_)
# Out:
# I 	 PRON 	 4690420944186131903 	 I
# am 	 AUX 	 10382539506755952630 	 be
# a 	 DET 	 11901859001352538922 	 a
# runner 	 NOUN 	 12640964157389618806 	 runner
# running 	 VERB 	 12767647472892411841 	 run
# in 	 ADP 	 3002984154512732771 	 in
# a 	 DET 	 11901859001352538922 	 a
# race 	 NOUN 	 8048469955494714898 	 race
# because 	 SCONJ 	 16950148841647037698 	 because
# I 	 PRON 	 4690420944186131903 	 I
# love 	 VERB 	 3702023516439754181 	 love
# to 	 PART 	 3791531372978436496 	 to
# run 	 VERB 	 12767647472892411841 	 run
# since 	 SCONJ 	 10066841407251338481 	 since
# I 	 PRON 	 4690420944186131903 	 I
# ran 	 VERB 	 12767647472892411841 	 run
# today 	 NOUN 	 11042482332948150395 	 today

# %%
def show_lemmas(text):
  for token in text:
    print(f'{token.text:{12}} {token.pos_:{6}} {token.lemma:<{22}} {token.lemma_}')

# %%
doc2 = nlp(u"I saw ten mice today!")

# %%
show_lemmas(doc2)
# Out:
# I            PRON   4690420944186131903    I
# saw          VERB   11925638236994514241   see
# ten          NUM    7970704286052693043    ten
# mice         NOUN   1384165645700560590    mouse
# today        NOUN   11042482332948150395   today
# !            PUNCT  17494803046312582752   !

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'top', 'n‘t', 'he', 'i', 'none', 'done', 'everyone', 'go', 'thru', 'whose', 'you', 'fifteen', 'should', 'herein', 'of', 'however', 'hundred', 'how', 'eight', 'hereafter', 'that', 'his', 'nowhere', 'almost', 'yours', 'often', 'please', "'re", 'full', 'neither', 'twelve', 'six', 'some', 'though', "'ve", 'forty', 'must', 'herself', 'always', 'whereupon', 'sometimes', 'whole', 'will', 'are', 'again', 'also', 'put', 'thence', 'thereafter', 'because', 'against', 'within', 'former', 'enough', 'everywhere', 'her', 'not', 'several', 'one', 'once', 'myself', 'whereby', 'hereby', 'throughout', 'with', 'do', 'both', 'using', 'next', 'were', 'take', 'there', 'among', 'made', 'various', 'whoever', 'quite', 'thus', 'under', 'became', 'without', 'an', 'otherwise', 'amongst', 'whither', '‘m', 'off', 'which', 'would', 'those', 'somewhere', 'everything', 'become', 'in', 'nothing', 'ourselves', 'who', 'side', 'onto', 'being', 'and', 'whereafter', 'but', 'name', 'the', 'therein', 'anywhere', 'am', 'make
# ...

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['is']

# %%
nlp.vocab['is'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('btw')

# %%
nlp.vocab['btw'].is_stop = True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
nlp.Defaults.stop_words.remove('btw')

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['btw'].is_stop = False

# %%
nlp.vocab['btw'].is_stop
# Out:
# False

# %%
from spacy.matcher import Matcher

# %%
matcher = Matcher(nlp.vocab)

# %%
# SolarPower
pattern1 = [{'LOWER':'solarpower'}]
# Solar-power
pattern2 = [{'LOWER':'solar'}, {'IS_PUNCT':True}, {'LOWER':'power'}]
# Solar power
pattern3 = [{'LOWER':'solar'},{'LOWER':'power'}]

# %%
matcher.add('SolarPower', [pattern1, pattern2, pattern3])

# %%
doc = nlp(u"The Solar Power industry continues to grow a solarpower increases. Solar-power is amazing.")

# %%
found_matches = matcher(doc)

# %%
print(found_matches)
# Out:
# [(8656102463236116519, 1, 3), (8656102463236116519, 8, 9), (8656102463236116519, 11, 14)]

# %%
for match_id, start, end in found_matches:
  string_id = nlp.vocab.strings[match_id]
  span = doc[start:end]
  print(match_id, string_id, start, end, span.text)
# Out:
# 8656102463236116519 SolarPower 1 3 Solar Power
# 8656102463236116519 SolarPower 8 9 solarpower
# 8656102463236116519 SolarPower 11 14 Solar-power

# %%
pattern1 = [{'LOWER':'solarpower'}]
pattern2 = [{'LOWER':'solar'},{'IS_PUNCT':True, 'OP':'*'}, {'LOWER':'power'}]

# %%
matcher.add('SolarPower',[pattern1, pattern2])

# %%
doc2 = nlp(u"Solar--power is solarpower yay!")

# %%
found_matches = matcher(doc2)

# %%
print(found_matches)
# Out:
# [(8656102463236116519, 0, 3), (8656102463236116519, 4, 5)]

# %%
from spacy.matcher import PhraseMatcher

# %%
matcher = PhraseMatcher(nlp.vocab)

# %%
with open('/home/vboxuser/Downloads/UPDATED_NLP_COURSE/TextFiles/reaganomics.txt',
          encoding='utf-8', errors='ignore') as f:
    doc3 = nlp(f.read())

# %%
phrase_list = ['voodoo economics','supply-side economics','trickle-down economics','free-market economics']

# %%
phrase_patterns = [nlp(text) for text in phrase_list]

# %%
phrase_patterns[0]
# Out:
# voodoo economics

# %%
type(phrase_patterns[0])
# Out:
# spacy.tokens.doc.Doc

# %%
matcher.add('EcoMatcher',None,*phrase_patterns)

# %%
found_matches
# Out:
# [(8656102463236116519, 0, 3), (8656102463236116519, 4, 5)]

# %%
for match_id, start, end in found_matches:
  string_id = nlp.vocab.strings[match_id]
  span = doc3[start:end]
  print(match_id, string_id, start, end, span.text)
# Out:
# 8656102463236116519 SolarPower 0 3 REAGANOMICS
# https://en.wikipedia.org/wiki/Reaganomics
# 8656102463236116519 SolarPower 4 5 Reaganomics

# %%
for match_id, start, end in found_matches:
  string_id = nlp.vocab.strings[match_id]
  span = doc3[start-5:end+5]
  print(match_id, string_id, start, end, span.text)
# Out:
# 8656102463236116519 SolarPower 0 3
# 8656102463236116519 SolarPower 4 5

# %%
with open('/home/vboxuser/Downloads/UPDATED_NLP_COURSE/TextFiles/owlcreek.txt',
          encoding='utf-8', errors='ignore') as f:
    doc = nlp(f.read())

# %%
doc[:36]
# Out:
# AN OCCURRENCE AT OWL CREEK BRIDGE
#
# by Ambrose Bierce
#
# I
#
# A man stood upon a railroad bridge in northern Alabama, looking down
# into the swift water twenty feet below.

# %%
len(doc)
# Out:
# 4835

# %%
doc_sentences = [sent for sent in doc.sents]

# %%
len(doc_sentences)
# Out:
# 204

# %%
print(doc_sentences[1].text)
# Out:
# The man's hands were behind
# his back, the wrists bound with a cord.

# %%
for token in doc_sentences[1]:
    print(f"{token.text} {token.pos_} {token.dep_} {token.lemma_}")
# Out:
# The DET det the
# man NOUN poss man
# 's PART case 's
# hands NOUN nsubj hand
# were AUX ROOT be
# behind ADP prep behind
#
#  SPACE dep
#
# his PRON poss his
# back NOUN pobj back
# , PUNCT punct ,
# the DET det the
# wrists NOUN appos wrist
# bound VERB acl bind
# with ADP prep with
# a DET det a
# cord NOUN pobj cord
# . PUNCT punct .
#   SPACE dep

# %%
for token in doc_sentences[1]:
    print(f"{token.text:{15}} {token.pos_:{5}} {token.dep_:{10}} {token.lemma_:{15}}")
# Out:
# The             DET   det        the
# man             NOUN  poss       man
# 's              PART  case       's
# hands           NOUN  nsubj      hand
# were            AUX   ROOT       be
# behind          ADP   prep       behind
#
#                SPACE dep
#
# his             PRON  poss       his
# back            NOUN  pobj       back
# ,               PUNCT punct      ,
# the             DET   det        the
# wrists          NOUN  appos      wrist
# bound           VERB  acl        bind
# with            ADP   prep       with
# a               DET   det        a
# cord            NOUN  pobj       cord
# .               PUNCT punct      .
#                 SPACE dep

# %%
pattern = [{'LOWER':'swimming'}, {'IS_SPACE':True,'OP':'*'},{'LOWER':'vigorously'}]

# %%
matcher = Matcher(nlp.vocab)

# %%
matcher.add("Swimming", [pattern])

# %%
found_matches = matcher(doc)

# %%
print(found_matches)
# Out:
# [(12881893835109366681, 1274, 1277), (12881893835109366681, 3609, 3612)]

# %%
def surrounding(doc,start,end):
  print(doc[start-10:end+5])

# %%
surrounding(doc,1274, 1277)
# Out:
#  By diving I could evade the bullets and, swimming
# vigorously, reach the bank,

# %%
surrounding(doc,3609, 3612)
# Out:
# saw all this over his shoulder; he was now swimming
# vigorously with the current.

# %%
for sentence in doc_sentences:
  if found_matches[0][1] < sentence.end:
    print(sentence)
    break
# Out:
# By diving I could evade the bullets and, swimming
# vigorously, reach the bank, take to the woods and get away home.

# %%
for sentence in doc_sentences:
  if found_matches[1][1] < sentence.end:
    print(sentence)
    break
# Out:
# The hunted man saw all this over his shoulder; he was now swimming
# vigorously with the current.

# %%
# with open('/home/vboxuser/Downloads/UPDATED_NLP_COURSE/TextFiles/reaganomics.txt',
#           encoding='utf-8', errors='ignore') as f:
#     doc3 = nlp(f.read())

# %%
doc = nlp(u"The quick brown fox jumped over the lazy dog's back.")

# %%
print(doc.text)
# Out:
# The quick brown fox jumped over the lazy dog's back.

# %%
print(doc[4].tag_)
# Out:
# VBD

# %%
print(doc[4].pos_)
# Out:
# VERB

# %%
for token in doc:
  print(f"{token.text:{10}} {token.pos_:{10}} {token.tag_:{7}} {spacy.explain(token.tag_)}")
# Out:
# The        DET        DT      determiner
# quick      ADJ        JJ      adjective (English), other noun-modifier (Chinese)
# brown      ADJ        JJ      adjective (English), other noun-modifier (Chinese)
# fox        NOUN       NN      noun, singular or mass
# jumped     VERB       VBD     verb, past tense
# over       ADP        IN      conjunction, subordinating or preposition
# the        DET        DT      determiner
# lazy       ADJ        JJ      adjective (English), other noun-modifier (Chinese)
# dog        NOUN       NN      noun, singular or mass
# 's         PART       POS     possessive ending
# back       NOUN       NN      noun, singular or mass
# .          PUNCT      .       punctuation mark, sentence closer

# %%
doc = nlp(u"I read books on NLP.")

# %%
word = doc[1]

# %%
word.text
# Out:
# 'read'

# %%
token= word
print(f"{token.text:{10}} {token.pos_:{10}} {token.tag_:{7}} {spacy.explain(token.tag_)}")
# Out:
# read       VERB       VBP     verb, non-3rd person singular present

# %%
doc = nlp(u"I read a book on NLP.")

# %%
word = doc[1]
for token in doc:
  print(f"{token.text:{10}} {token.pos_:{10}} {token.tag_:{7}} {spacy.explain(token.tag_)}")
# Out:
# I          PRON       PRP     pronoun, personal
# read       VERB       VBD     verb, past tense
# a          DET        DT      determiner
# book       NOUN       NN      noun, singular or mass
# on         ADP        IN      conjunction, subordinating or preposition
# NLP        PROPN      NNP     noun, proper singular
# .          PUNCT      .       punctuation mark, sentence closer

# %%
word = doc[1]
token = word
print(f"{token.text:{10}} {token.pos_:{10}} {token.tag_:{7}} {spacy.explain(token.tag_)}")
# Out:
# read       VERB       VBD     verb, past tense

# %%
doc = nlp("The quick brown fox jumped over the lazy dog's back.")

# %%
POS_coutns = doc.count_by(spacy.attrs.POS)

# %%
POS_coutns
# Out:
# {90: 2, 84: 3, 92: 3, 100: 1, 85: 1, 94: 1, 97: 1}

# %%
doc.vocab[84].text
# Out:
# 'ADJ'

# %%
doc[2].pos
# Out:
# <univ_pos_t.ADJ: 84>

# %%
for k,v in sorted(POS_coutns.items()):
  print(f"{k}. {doc.vocab[k].text:{5}} {v}")
# Out:
# 84. ADJ   3
# 85. ADP   1
# 90. DET   2
# 92. NOUN  3
# 94. PART  1
# 97. PUNCT 1
# 100. VERB  1

# %%
TAG_counts = doc.count_by(spacy.attrs.TAG)

for k,v in sorted(TAG_counts.items()):
  print(f"{k}. {doc.vocab[k].text:{5}} {v}")
# Out:
# 74. POS   1
# 1292078113972184607. IN    1
# 10554686591937588953. JJ    3
# 12646065887601541794. .     1
# 15267657372422890137. DT    2
# 15308085513773655218. NN    3
# 17109001835818727656. VBD   1

# %%
len(doc.vocab)
# Out:
# 3352

# %%
DEP_counts = doc.count_by(spacy.attrs.DEP)

for k,v in sorted(DEP_counts.items()):
  print(f"{k}. {doc.vocab[k].text:{5}} {v}")
# Out:
# 402. amod  3
# 415. det   2
# 429. nsubj 1
# 439. pobj  1
# 440. poss  1
# 443. prep  1
# 445. punct 1
# 8110129090154140942. case  1
# 8206900633647566924. ROOT  1

# %%
doc = nlp(u"The quick brown fox jumped over the lazy dog.")

# %%
from spacy import displacy

# %%
displacy.render(doc,style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f53fc86f52ea4b77ac10a4b483fa6d74-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
options = {'distance':90,'compact':'True','color':'yellow','bg':'#09a3d5','font':'Times'}

# %%
displacy.render(doc,style='dep',jupyter=True,options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7d80182be538435280ab60a4151e4756-0" class="displacy" width="860" height="272.0" direction="ltr" style="max-width: none; height: 272.0px; color: yellow; background: #09a3d5; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
# ...

# %%
doc2 = nlp(u"This a sentece. This is another sentence, possibly longer than the other.")

# %%
spans = list(doc2.sents)

# %%
displacy.serve(spans,style='dep',options={'distance':90})
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7a1d0607af5e4ef58d999c9cf3affcbd-0" class="displacy" width="320" height="227.0" direction="ltr" style="max-width: none; height: 227.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# ...
