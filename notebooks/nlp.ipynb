# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')
# nlp = spacy.load('pt_core_news_sm')

# %%
doc = nlp(u'Tesla is look at buying U.S. startup for $6 million')

# %%
for token in doc:
  print(token.text)
# Out:
# Tesla
# is
# look
# at
# buying
# U.S.
# startup
# for
# $
# 6
# million

# %%
for token in doc:
  print(token.text,token.pos)
# Out:
# Tesla 96
# is 87
# look 100
# at 85
# buying 100
# U.S. 96
# startup 100
# for 85
# $ 99
# 6 93
# million 93

# %%
for token in doc:
  print(token.text,token.pos_)
# Out:
# Tesla PROPN
# is AUX
# look VERB
# at ADP
# buying VERB
# U.S. PROPN
# startup VERB
# for ADP
# $ SYM
# 6 NUM
# million NUM

# %%
for token in doc:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubjpass
# is AUX auxpass
# look VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.S. PROPN dobj
# startup VERB dobj
# for ADP prep
# $ SYM quantmod
# 6 NUM compound
# million NUM pobj

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7cbb4f20eff0>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7cbb4f20e4b0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7cbb4f1bdd20>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7cbb60162910>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7cbb4efc8b50>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7cbb4f1bdfc0>)]

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc2 = nlp(u"Tesla isn't looking into startups anymore.")

# %%
for token in doc2:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc2 = nlp(u"Tesla isn't     looking into startups anymore.")

# %%
for token in doc2:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
#      SPACE dep
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc2[0]
# Out:
# Tesla

# %%
doc2[0].pos_
# Out:
# 'PROPN'

# %%
doc2[0].dep_
# Out:
# 'nsubj'

# %%
print(doc2[6].text)
# Out:
# startups

# %%
print(doc2[6].lemma_)
# Out:
# startup

# %%
print(doc2[6].is_alpha)
# Out:
# True

# %%
doc3 = nlp(u'Althoug commmoly attributed to John Lennon from his song "Beautiful Boy", \
           the phrase "Life is what happens to us while we are making other plans" was written by \
           cartoonist Allen Saunders and published in Reader\'s Digest in 1927, when Lennon was 17')

# %%
life_quote = doc3[16:30]

# %%
print(life_quote)
# Out:
# phrase "Life is what happens to us while we are making other plans

# %%
type(life_quote)
# Out:
# spacy.tokens.span.Span

# %%
type(doc3)
# Out:
# spacy.tokens.doc.Doc

# %%
doc4 = nlp(u"this is the first sentence. This is another sentence. This is the last sentence")

# %%
for sentence in doc4.sents:
  print(sentence)
# Out:
# this is the first sentence.
# This is another sentence.
# This is the last sentence

# %%
doc4[6]
# Out:
# This

# %%
doc4[6].is_sent_start
# Out:
# True

# %%
doc4[8].is_sent_start
# Out:
# False

# %%
mystring = '"We\'re moving to L.A.!"'

# %%
print(mystring)
# Out:
# "We're moving to L.A.!"

# %%
doc = nlp(mystring)

# %%
for token in doc:
  print(token.text)
# Out:
# "
# We
# 're
# moving
# to
# L.A.
# !
# "

# %%
doc2 = nlp(u"We're here to help! Send snail-mail, email support@oursite.com or visit us at http://www.oursite.com!")

# %%
for t in doc2:
  print(t)
# Out:
# We
# 're
# here
# to
# help
# !
# Send
# snail
# -
# mail
# ,
# email
# support@oursite.com
# or
# visit
# us
# at
# http://www.oursite.com
# !

# %%
doc3 = nlp(u"A 5km NYC cab ride costs $10.30")

# %%
for t in doc3:
  print(t)
# Out:
# A
# 5
# km
# NYC
# cab
# ride
# costs
# $
# 10.30

# %%
doc4 = nlp(u"Let's visit St. Louis in the U.S. next year.")

# %%
for t in doc4:
  print(t)
# Out:
# Let
# 's
# visit
# St.
# Louis
# in
# the
# U.S.
# next
# year
# .

# %%
len(doc4)
# Out:
# 11

# %%
doc4.vocab

# %%
len(doc4.vocab)
# Out:
# 837

# %%
doc5 = nlp(u"It is better to give than receive")

# %%
doc5[0]
# Out:
# It

# %%
doc5[2:5]
# Out:
# better to give

# %%
doc5[0] = 'test'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 doc5[0] = 'test'
#
# TypeError: 'spacy.tokens.doc.Doc' object does not support item assignment

# %%
doc8 = nlp(u"Apple to build a Hong Kong factroy for $6 million")

# %%
for token in doc8:
  print(token.text, end=' | ')
# Out:
# Apple | to | build | a | Hong | Kong | factroy | for | $ | 6 | million |

# %%
for entity in doc8.ents:
  print(entity)
# Out:
# Apple
# Hong Kong
# $6 million

# %%
for entity in doc8.ents:
  print(entity)
  print(entity.label_)
  print(str(spacy.explain(entity.label_)))
  print('\n')
# Out:
# Apple
# ORG
# Companies, agencies, institutions, etc.
#
#
# Hong Kong
# GPE
# Countries, cities, states
#
#
# $6 million
# MONEY
# Monetary values, including unit

# %%
doc9 = nlp(u"Autonomous cars shift insurance liability toward manufacturers.")

# %%
for chunck in doc9.noun_chunks:
  print(chunck)
# Out:
# Autonomous cars
# insurance liability
# manufacturers

# %%
from spacy import displacy

# %%
doc = nlp(u"Apple is going to build a U.K. factory for $6 million.")

# %%
displacy.render(doc,style='dep', jupyter='True',options={'distance':110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="93355517655d4fc08873780378dbe5b2-0" class="displacy" width="1370" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">U.K.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">factory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">million.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93355517655d4fc08873780378dbe5b2-0-0" stroke-width="2px" d="M70,222.0 C70,112.0 260.0,112.0 260.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93355517655d4fc08873780378dbe5b2-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,224.0 L62,212.0 78,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93355517655d4fc08873780378dbe5b2-0-1" stroke-width="2px" d="M180,222.0 C180,167.0 255.0,167.0 255.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93355517655d4fc08873780378dbe5b2-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,224.0 L172,212.0 188,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93355517655d4fc08873780378dbe5b2-0-2" stroke-width="2px" d="M400,222.0 C400,167.0 475.0,167.0 475.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93355517655d4fc08873780378dbe5b2-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,224.0 L392,212.0 408,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93355517655d4fc08873780378dbe5b2-0-3" stroke-width="2px" d="M290,222.0 C290,112.0 480.0,112.0 480.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93355517655d4fc08873780378dbe5b2-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M480.0,224.0 L488.0,212.0 472.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93355517655d4fc08873780378dbe5b2-0-4" stroke-width="2px" d="M620,222.0 C620,112.0 810.0,112.0 810.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93355517655d4fc08873780378dbe5b2-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M620,224.0 L612,212.0 628,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93355517655d4fc08873780378dbe5b2-0-5" stroke-width="2px" d="M730,222.0 C730,167.0 805.0,167.0 805.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93355517655d4fc08873780378dbe5b2-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M730,224.0 L722,212.0 738,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93355517655d4fc08873780378dbe5b2-0-6" stroke-width="2px" d="M510,222.0 C510,57.0 815.0,57.0 815.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93355517655d4fc08873780378dbe5b2-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M815.0,224.0 L823.0,212.0 807.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93355517655d4fc08873780378dbe5b2-0-7" stroke-width="2px" d="M510,222.0 C510,2.0 930.0,2.0 930.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93355517655d4fc08873780378dbe5b2-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M930.0,224.0 L938.0,212.0 922.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93355517

# %%
doc = nlp(u"Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million.")

# %%
displacy.render(doc,style='ent', jupyter='True')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  iPods for a profit of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>

# %%
doc = nlp(u"This is a sentence.")
displacy.serve(doc,style='dep')
# Out:
# /home/vboxuser/Documents/nlp/.venv/lib/python3.11/site-packages/spacy/displacy/__init__.py:108: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3c6b90581c144ca8bcd3b920fc29e155-0" class="displacy" width="750" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">sentence.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3c6b90581c144ca8bcd3b920fc29e155-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3c6b90581c144ca8bcd3b920fc29e155-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3c6b90581c144ca8bcd3b920fc29e155-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3c6b90581c144ca8bcd3b920fc29e155-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3c6b90581c144ca8bcd3b920fc29e155-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3c6b90581c144ca8bcd3b920fc29e155-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# </figure>
# </body>
# </html></span>
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
# 127.0.0.1 - - [05/Mar/2026 08:36:14] "GET / HTTP/1.1" 200 3395
# 127.0.0.1 - - [05/Mar/2026 08:36:15] "GET /favicon.ico HTTP/1.1" 200 3395
# Shutting down server on port 5000.

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer

# %%
p_stemmer = PorterStemmer()

# %%
words = ['run','runner','ran','runs','easily','fairly','fairness']

# %%
for word in words:
  print(word + '----->' +p_stemmer.stem(word))
# Out:
# run----->run
# runner----->runner
# ran----->ran
# runs----->run
# easily----->easili
# fairly----->fairli
# fairness----->fair

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
s_stemmer = SnowballStemmer(language='english')

# %%
for word in words:
  print(word + '  ----->' +s_stemmer.stem(word))
# Out:
# run  ----->run
# runner  ----->runner
# ran  ----->ran
# runs  ----->run
# easily  ----->easili
# fairly  ----->fair
# fairness  ----->fair

# %%
words = ['generous','generation','generously','generate']

# %%
for word in words:
  print(word + '  ----->' +s_stemmer.stem(word))
# Out:
# generous  ----->generous
# generation  ----->generat
# generously  ----->generous
# generate  ----->generat

# %%
doc1 = nlp(u"I am a runner running in a race because I love to run since I ran today")

# %%
for token in doc1:
  print(token.text,'\t',token.pos_,'\t',token.lemma,'\t',token.lemma_)
# Out:
# I 	 PRON 	 4690420944186131903 	 I
# am 	 AUX 	 10382539506755952630 	 be
# a 	 DET 	 11901859001352538922 	 a
# runner 	 NOUN 	 12640964157389618806 	 runner
# running 	 VERB 	 12767647472892411841 	 run
# in 	 ADP 	 3002984154512732771 	 in
# a 	 DET 	 11901859001352538922 	 a
# race 	 NOUN 	 8048469955494714898 	 race
# because 	 SCONJ 	 16950148841647037698 	 because
# I 	 PRON 	 4690420944186131903 	 I
# love 	 VERB 	 3702023516439754181 	 love
# to 	 PART 	 3791531372978436496 	 to
# run 	 VERB 	 12767647472892411841 	 run
# since 	 SCONJ 	 10066841407251338481 	 since
# I 	 PRON 	 4690420944186131903 	 I
# ran 	 VERB 	 12767647472892411841 	 run
# today 	 NOUN 	 11042482332948150395 	 today

# %%
def show_lemmas(text):
  for token in text:
    print(f'{token.text:{12}} {token.pos_:{6}} {token.lemma:<{22}} {token.lemma_}')

# %%
doc2 = nlp(u"I saw ten mice today!")

# %%
show_lemmas(doc2)
# Out:
# I            PRON   4690420944186131903    I
# saw          VERB   11925638236994514241   see
# ten          NUM    7970704286052693043    ten
# mice         NOUN   1384165645700560590    mouse
# today        NOUN   11042482332948150395   today
# !            PUNCT  17494803046312582752   !

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'thus', 'mine', 'at', 'yourself', 'four', 'once', 'always', 'themselves', '’s', 'last', 'never', 'therefore', 'per', 'meanwhile', 'anywhere', 'now', 'and', 'towards', 'afterwards', '’re', 'anyway', 'may', 'fifty', 'too', 'noone', 'should', 'him', 'same', 'however', '’ll', 'we', 'next', 'amount', 'whereupon', 'against', 'whereafter', "'m", 'upon', 'this', 'make', 'whom', 'yet', 'beforehand', 'there', '‘ve', 'became', 'is', 'third', '‘s', 'that', 'be', 'also', 'everywhere', 'fifteen', 'indeed', 'was', 'from', 'amongst', 'besides', 'were', 'three', 'empty', 'to', 'well', 'nor', 'many', 'five', 'because', 'their', 'very', 'between', 'nine', "'ve", 'someone', 'below', 'back', 'btw', 'except', 'often', 'have', 'whereby', 'thereafter', 'might', 'whether', 'could', 'a', '’ve', 'without', 'anything', 'get', 'least', 'of', 'until', 'whoever', 'any', 'been', 'down', 'other', 'with', 'due', 'become', 'will', 'twenty', 'whither', 'up', 'being', 'i', 'none', 'becoming', 'elsewhere', 'using', 'seeming', 'somewhere', 'another', 'thence', 'still', 'take', 'yours', 'see', 'used', 'no', 'whereas', 'ten', 'give', 'through', 'nowhere', 'me', 'my', 'almost', 'did', 'onto', 'six', 'toward', 'am', 'although', 'everyone', 'why', 'own', 'hence', 'your', 'one', 'part', 'do', 'hereafter', 'former', 'further', 'during', 'move', 'whose', 'done', 'nothing', 'about', "'d", 'already', 'those', 'beside', 'more', 'out', 'above', 'most', 'nobody', 'just', 'where', 'he', 'put', 'must', 'quite', 'these', 'anyone', 'say', 'seems', 'herself', 'mostly', 'sometime', 'off', 'rather', 'somehow', 'both', 'formerly', 'few', 'otherwise', 'several', 'namely', 'show', 'here', 'something', 'full', 'itself', 'wherever', 'thereupon', 'along', 'over', 'made', 'but', 'eight', 'side', 'across', 'on', 'while', 'top', 'hers', 'name', 'less', 'go', 'thereby', 'ourselves', 'each', 'via', 'then', 'latter', 'so', 'moreover', 'not', '‘re', 'before', 'ca', 'some', 'are', 'only', 'whatever', "'s", '‘m', 'has', 'perhaps', 'alone', 'beyond', 'you', 'therein', 'unless', 'either', 'as', 'keep', 'what', 'how', 'does', 'n‘t', 'becomes', 'please', 'than', 'cannot', 'two', 'n’t', 'latterly', '‘d', 'ours', 'into', 'since', '’m', '‘ll', 'by', "'re", 'had', 'they', 'for', 'really', 'around', 'call', 'when', 'though', 'regarding', 'it', 'she', 'the', 'else', 'herein', 'others', 'himself', 'which', 'twelve', 'various', 'seem', 'anyhow', 'enough', 'whenever', 'an', 'doing', 'such', 'neither', 'front', 'even', 'our', 'thru', 'its', 'within', 'her', 'behind', '’d', 'among', 'or', 'would', 'eleven', 'throughout', 'all', 'hundred', 'serious', 're', 'under', "'ll", 'hereby', 'yourselves', 'everything', 'nevertheless', 'myself', 'ever', 'can', 'them', 'wherein', 'after', "n't", 'forty', 'again', 'bottom', 'hereupon', 'every', 'together', 'whole', 'in', 'if', 'sometimes', 'us', 'much', 'who', 'first', 'his', 'sixty', 'seemed', 'whence'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['is']

# %%
nlp.vocab['is'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('btw')

# %%
nlp.vocab['btw'].is_stop = True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
nlp.Defaults.stop_words.remove('btw')

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['btw'].is_stop = False

# %%
nlp.vocab['btw'].is_stop
# Out:
# False

# %%
from spacy.matcher import Matcher

# %%
matcher = Matcher(nlp.vocab)

# %%
# SolarPower
pattern1 = [{'LOWER':'solarpower'}]
# Solar-power
pattern2 = [{'LOWER':'solar'}, {'IS_PUNCT':True}, {'LOWER':'power'}]
# Solar power
pattern3 = [{'LOWER':'solar'},{'LOWER':'power'}]

# %%
matcher.add('SolarPower', [pattern1, pattern2, pattern3])

# %%
doc = nlp(u"The Solar Power industry continues to grow a solarpower increases. Solar-power is amazing.")

# %%
found_matches = matcher(doc)

# %%
print(found_matches)
# Out:
# [(8656102463236116519, 1, 3), (8656102463236116519, 8, 9), (8656102463236116519, 11, 14)]

# %%
for match_id, start, end in found_matches:
  string_id = nlp.vocab.strings[match_id]
  span = doc[start:end]
  print(match_id, string_id, start, end, span.text)
# Out:
# 8656102463236116519 SolarPower 1 3 Solar Power
# 8656102463236116519 SolarPower 8 9 solarpower
# 8656102463236116519 SolarPower 11 14 Solar-power

# %%
pattern1 = [{'LOWER':'solarpower'}]
pattern2 = [{'LOWER':'solar'},{'IS_PUNCT':True, 'OP':'*'}, {'LOWER':'power'}]

# %%
matcher.add('SolarPower',[pattern1, pattern2])

# %%
doc2 = nlp(u"Solar--power is solarpower yay!")

# %%
found_matches = matcher(doc2)

# %%
print(found_matches)
# Out:
# [(8656102463236116519, 0, 3), (8656102463236116519, 4, 5)]
